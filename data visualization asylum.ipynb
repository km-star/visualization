# %% [markdown]
# # Kumar Mahat(18BCE2474)

# %% [markdown]
# # I have implemented some visualization techniques of the dataset using python.i.e (jupyter notebook). Here I have used the pyplot, seaborn packages to visualize my data in more effective and efficient way. Since the code is implemented in jupyter_notebook some screenshots are taken and pasted here. In the code we have plotted the graph in the form of barplot, piechart, scatterplot and heatmap.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#%matplotlib inline
ASM=pd.read_csv('C:\\Users\\Dell\\asylum_seekers_monthly.xls')
ASM
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        territory_of_asylum       Origin  Year     Month Value
# 0                Australia  Afghanistan  1999   January     8
# 1                Australia  Afghanistan  1999  February    10
# 2                Australia  Afghanistan  1999     March    25
# 3                Australia  Afghanistan  1999     April    25
# 4                Australia  Afghanistan  1999       May     7
# ...                    ...          ...   ...       ...   ...
# 332184       USA (INS/DHS)     Zimbabwe  2016  December    28
# 332185       USA (INS/DHS)     Zimbabwe  2017  February    27
# 332186       USA (INS/DHS)     Zimbabwe  2017     March    42
# 332187       USA (INS/DHS)     Zimbabwe  2017     April    16
# ...

# %%
origin_plot=ASM.Origin.value_counts().plot(kind="bar",x=ASM["Origin"],title="Countries from which most people migrate",legend=True)
fig = origin_plot.get_figure()
plt.figure(figsize=(750,300))

# %% [markdown]
# # For Barplot Visualization:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
ASM=pd.read_csv("C:\\Users\\Dell\\asylum_seekers_monthly.xls")
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
x=ASM["Origin"]
x=list(dict.fromkeys(x))
y=ASM.Origin.value_counts()
print(y)
y.plot(kind="bar",x=ASM["Origin"],legend="True")
ax.set_title("Countries from which most people migrate",fontsize="20")
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Iraq                                6367
# Iran (Islamic Rep. of)              6207
# Afghanistan                         6122
# Pakistan                            6109
# Nigeria                             5844
#                                     ...
# French Guiana                          5
# Liechtenstein                          5
# Micronesia (Federated States of)       5
# Puerto Rico                            5
# New Caledonia                          4
# Name: Origin, Length: 205, dtype: int64
# Text(0.5, 1.0, 'Countries from which most people migrate')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
ASM=pd.read_csv("C:\\Users\\Dell\\asylum_seekers_monthly.xls")
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
x=ASM["territory_of_asylum"]
x=list(dict.fromkeys(x))
y=ASM.territory_of_asylum.value_counts()
print(y)
y.plot(kind="bar",x=ASM["territory_of_asylum"],legend="True")
ax.set_title("Countries to which most people migrate",fontsize="20")
fig.set_size_inches(15,10)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Canada                                                  25693
# USA (INS/DHS)                                           19734
# USA (EOIR)                                              18559
# Germany                                                 18147
# France                                                  17870
# United Kingdom of Great Britain and Northern Ireland    17709
# Sweden                                                  17035
# Belgium                                                 16336
# Switzerland                                             15404
# Netherlands                                             14548
# Norway                                                  11978
# ...

# %% [markdown]
# # For Pie-chart Visualization:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=pd.read_csv("C:\\Users\\Dell\\asylum_seekers_monthly.xls")
y=data.Origin.value_counts()
val=[]
sta=[]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
for x in range(0,len(y),1):
    if(y[x]>=30):
         val.append(y[x])
key=y.keys()
for i in range(0,len(val),1):
 sta.append(key[i])
ax.pie(val,labels=sta,autopct='%1.2f%%')
fig.set_size_inches(18.5, 10.5)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # For Scatter-Plot Visualization:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
ASM=pd.read_csv("C:\\Users\\Dell\\asylum_seekers_monthly.xls")
df = pd.DataFrame(ASM)
df['Value'] = pd.to_numeric(df['Value'],errors='coerce')
df = df.replace(np.nan, 0, regex=True)
df['Value'] = df['Value'].astype(int)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x=df["Year"]
y=df["Value"]
ax.set_xlabel("Year",fontsize="20")
ax.set_ylabel("Value",fontsize="20")
ax.set_title("Immigrants accordind to year between 1999 to 2016",fontsize="20"
)
ax.scatter(x,y)
fig.set_size_inches(15,10)

# %% [markdown]
# # For Heatmap Visualization:

# %%
#data preprocessing

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

ASM= pd.read_csv("C:\\Users\\Dell\\asylum_seekers_monthly.xls")
df = pd.DataFrame(ASM)
df.isna().sum()
df[df.Value=='*']
df=df[df.Value!='*']

# %%
df['Value']=pd.to_numeric(df['Value'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320348 entries, 0 to 332188
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   territory_of_asylum  320348 non-null  object
#  1   Origin               320348 non-null  object
#  2   Year                 320348 non-null  int64
#  3   Month                320348 non-null  object
#  4   Value                320348 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#data visualization

grouped_df =df.groupby(['territory_of_asylum','Origin'])['Year'].count().reset_index()
grouped_df = grouped_df.pivot('territory_of_asylum', 'Origin', 'Year')
grouped_df.head()
plt.figure(figsize=(20,20))
sns.heatmap(grouped_df,cmap="YlGnBu")
plt.title("Heatmap showing territory_of_asylum vs Origin in yearwise")
plt.show()

# %%
#more to be continued
